# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC 
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, roc_curve
from sklearn.metrics import confusion_matrix

# %%
import pandas as pd 
import numpy as np                     # For mathematical calculations 
import seaborn as sns                  # For data visualization 
import matplotlib.pyplot as plt        
# %matplotlib inline

# %%
train=pd.read_csv("C:/Users/TEMP/Desktop/train.csv") 
#test=pd.read_csv("C:/Users/TEMP/Desktop/test.csv")

# %%
print(train.describe())
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
print(train.dtypes)
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
print(train.head())
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
train_original=train.copy()

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
#test.columns

# %%
train.shape
# Out:
# (2000, 21)

# %%
train['price_range'].value_counts()  #count the values
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %%
# Normalize can be set to True to 
# print proportions instead of number train
train['price_range'].value_counts(normalize=True)
# Out:
# 3    0.25
# 2    0.25
# 1    0.25
# 0    0.25
# Name: price_range, dtype: float64

# %%
train['blue'].value_counts(normalize=True)
# Out:
# 0    0.505
# 1    0.495
# Name: blue, dtype: float64

# %%
train['price_range'].value_counts().plot.bar()

# %%
# Independent Variable (Categorical)

# %%
import matplotlib.pyplot as plt 
plt.figure(1) 

plt.subplot(221)
train['blue'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'blue') 

plt.subplot(222) 
train['dual_sim'].value_counts(normalize=True).plot.bar(title= 'dual_sim') 

plt.subplot(223) 
train['four_g'].value_counts(normalize=True).plot.bar(title= 'four_g') 

plt.subplot(224) 
train['three_g'].value_counts(normalize=True).plot.bar(title= 'three_g')

"""
plt.subplot(225)
train['touch_screen'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'touch_screen')

plt.subplot(226)
train['wifi'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'wifi')"""



plt.show()

# %%
import matplotlib.pyplot as plt 
plt.figure(1) 

train['touch_screen'].value_counts(normalize=True).plot.bar(figsize=(4,4), title= 'touch_screen')
plt.show()


train['wifi'].value_counts(normalize=True).plot.bar(figsize=(4,4), title= 'wifi')

plt.show()

# %%
#Independent Variable (Ordinal)

# %%
plt.figure(1) 

plt.subplot(131) 
train['price_range'].value_counts(normalize=True).plot.bar(figsize=(24,6), title= 'price_range') 


plt.show()

# %%
#Independent Variable (Numerical)

# %%
import seaborn as sns  
plt.figure(1) 


sns.distplot(train['battery_power']);
plt.show()


sns.distplot(train['clock_speed']);
plt.show()

sns.distplot(train['fc']);
plt.show()

sns.distplot(train['int_memory']);
plt.show()

sns.distplot(train['m_dep']);
plt.show()

sns.distplot(train['mobile_wt']);
plt.show()

sns.distplot(train['n_cores']);
plt.show()

sns.distplot(train['pc']);
plt.show()

sns.distplot(train['px_height']);
plt.show()

sns.distplot(train['px_width']);
plt.show()

sns.distplot(train['ram']);
plt.show()

sns.distplot(train['sc_h']);
plt.show()

sns.distplot(train['sc_w']);
plt.show()

sns.distplot(train['talk_time']);
plt.show()

# %%
train['battery_power'].plot.box(figsize=(10,5)) 
plt.show()


train['clock_speed'].plot.box(figsize=(10,5)) 
plt.show()


train['fc'].plot.box(figsize=(10,5)) 
plt.show()


train['int_memory'].plot.box(figsize=(10,5)) 
plt.show()


train['m_dep'].plot.box(figsize=(10,5)) 
plt.show()


train['mobile_wt'].plot.box(figsize=(10,5)) 
plt.show()

train['n_cores'].plot.box(figsize=(10,5)) 
plt.show()

train['pc'].plot.box(figsize=(10,5)) 
plt.show()

train['px_height'].plot.box(figsize=(10,5)) 
plt.show()

train['px_width'].plot.box(figsize=(10,5)) 
plt.show()

train['ram'].plot.box(figsize=(10,5)) 
plt.show()

train['sc_h'].plot.box(figsize=(10,5)) 
plt.show()

train['sc_w'].plot.box(figsize=(10,5)) 
plt.show()

train['talk_time'].plot.box(figsize=(10,5)) 
plt.show()

# %%
blue=pd.crosstab(train['blue'],train['price_range']) 
blue.div(blue.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
dual_sim=pd.crosstab(train['dual_sim'],train['price_range']) 
dual_sim.div(dual_sim.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
four_g=pd.crosstab(train['four_g'],train['price_range']) 
four_g.div(four_g.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
wifi=pd.crosstab(train['wifi'],train['price_range']) 
wifi.div(wifi.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
three_g=pd.crosstab(train['three_g'],train['price_range']) 
three_g.div(three_g.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
touch_screen=pd.crosstab(train['touch_screen'],train['price_range']) 
touch_screen.div(touch_screen.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
train_mod=train.drop('price_range',axis=1)

# %%
matrix = train_mod.corr()
plt.subplots(figsize=(9, 6)) 
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu");

# %% [markdown]
# from sklearn.model_selection import train_test_split
# X=train_mod
# y=train.price_range
# X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=train.price_range, random_state=0 )
# print(X_train.shape, y_train.shape)
# print(X_test.shape, y_test.shape)

# %%
from sklearn.model_selection import train_test_split 
X=train_mod 
y=train.price_range 
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=train.price_range, random_state=0 )
print(X_train.shape, y_train.shape) 
print(X_test.shape, y_test.shape)
# Out:
# (1500, 20) (1500,)
# (500, 20) (500,)

# %%
acc={}
#classifiers

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, roc_curve

# LOGISTIC REGRESSION #

lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
acc_lr=accuracy_score(y_test,y_pred)

"""fpr, tpr, thresholds = roc_curve(y_test,y_pred)

plt.plot([0, 1],[0, 1],'k--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for Logistic Regression')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')"""

#plt.grid(True)

acc['Logistic Regression']=accuracy_score(y_test, y_pred) * 100
print('\nLogistic Regression Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('Logistic Regression AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('Logistic Regression Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# F:\ml\WPy64-3720\python-3.7.2.amd64\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# F:\ml\WPy64-3720\python-3.7.2.amd64\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Logistic Regression Accuracy: 80.20%
# Logistic Regression Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       125
#            1       0.74      0.64      0.69       125
#            2       0.71      0.66      0.68       125
#            3       0.85      0.97      0.90       125
#
#    micro avg       0.80      0.80      0.80       500
#    macro avg       0.80      0.80      0.80       500
# ...

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for Logistic Regression'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[118   7   0   0]
#  [ 15  80  30   0]
#  [  0  21  82  22]
#  [  0   0   4 121]]

# %%
# STOCHASTIC GRADIENT DESCENT 

sgd=SGDClassifier()
sgd.fit(X_train,y_train)

y_pred = sgd.predict(X_test)
acc_sgd=accuracy_score(y_test,y_pred)



"""fpr, tpr, thresholds = roc_curve(
    y_test, 
    y_pred
)

plt.plot(
    [0, 1], 
    [0, 1], 
    'k--'
)

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for STOCHASTIC GRADIENT DESCENT')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')

plt.grid(True)"""

acc['STOCHASTIC GRADIENT DESCENT']=accuracy_score(y_test, y_pred) * 100

print('\nSTOCHASTIC GRADIENT DESCENT Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('STOCHASTIC GRADIENT DESCENT AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('STOCHASTIC GRADIENT DESCENT Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# STOCHASTIC GRADIENT DESCENT Accuracy: 45.20%
# STOCHASTIC GRADIENT DESCENT Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78       125
#            1       0.00      0.00      0.00       125
#            2       0.00      0.00      0.00       125
#            3       0.35      1.00      0.52       125
#
#    micro avg       0.45      0.45      0.45       500
#    macro avg       0.27      0.45      0.32       500
# weighted avg       0.27      0.45      0.32       500
# F:\ml\WPy64-3720\python-3.7.2.amd64\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# ...

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for STOCHASTIC GRADIENT DESCENT'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[101   0   6  18]
#  [ 34   0   1  90]
#  [  0   0   0 125]
#  [  0   0   0 125]]

# %%
#KNN

knn=KNeighborsClassifier()
knn.fit(X_train,y_train)

y_pred = knn.predict(X_test)
acc_knn=accuracy_score(y_test,y_pred)

"""fpr, tpr, thresholds = roc_curve(y_test,y_pred)

plt.plot([0, 1],[0, 1],'k--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for KNN')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')

plt.grid(True)"""


acc['KNN']=accuracy_score(y_test, y_pred) * 100


print('\nKNN Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('KNN AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('KNN Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# KNN Accuracy: 90.80%
# KNN Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       125
#            1       0.90      0.90      0.90       125
#            2       0.86      0.86      0.86       125
#            3       0.93      0.90      0.92       125
#
#    micro avg       0.91      0.91      0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for KNN'); 
ax.xaxis.set_ticklabels(['0','1','2','3' ]); ax.yaxis.set_ticklabels(['0','1','2','3' ]);
# Out:
# [[122   3   0   0]
#  [  7 112   6   0]
#  [  0  10 107   8]
#  [  0   0  12 113]]

# %%
# SVM ALGORITHM 

svclassifier = SVC(kernel='linear')  
svc=svclassifier.fit(X_train, y_train)  

y_pred = svclassifier.predict(X_test)
acc_svc=accuracy_score(y_test,y_pred)
#print(y_pred)
"""fpr, tpr, thresholds = roc_curve(y_test,y_pred)

plt.plot([0, 1],[0, 1],'k--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for SVM')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')

plt.grid(True)"""


acc['SVM']=accuracy_score(y_test, y_pred) * 100

print('\nSVM Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('SVM AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('SVM Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# SVM Accuracy: 97.00%
# SVM Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       125
#            1       0.95      0.97      0.96       125
#            2       0.95      0.98      0.96       125
#            3       0.99      0.97      0.98       125
#
#    micro avg       0.97      0.97      0.97       500
#    macro avg       0.97      0.97      0.97       500
# weighted avg       0.97      0.97      0.97       500

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for SVM'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[121   4   0   0]
#  [  2 121   2   0]
#  [  0   2 122   1]
#  [  0   0   4 121]]

# %%
# NAIVE BAYES

nb=GaussianNB()
nb.fit(X_train,y_train)

y_pred = nb.predict(X_test)
acc_nb=accuracy_score(y_test,y_pred)
"""fpr, tpr, thresholds = roc_curve(y_test,y_pred)

plt.plot([0, 1],[0, 1],'k--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for NAIVE BAYES')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')

plt.grid(True)"""


acc['NAIVE BAYES']=accuracy_score(y_test, y_pred) * 100

print('\nNAIVE BAYES Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('NAIVE BAYES AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('NAIVE BAYES Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# NAIVE BAYES Accuracy: 81.80%
# NAIVE BAYES Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       125
#            1       0.72      0.81      0.76       125
#            2       0.76      0.70      0.73       125
#            3       0.89      0.88      0.89       125
#
#    micro avg       0.82      0.82      0.82       500
#    macro avg       0.82      0.82      0.82       500
# weighted avg       0.82      0.82      0.82       500

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for NAIVE BAYES'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[110  15   0   0]
#  [ 11 101  13   0]
#  [  0  24  88  13]
#  [  0   0  15 110]]

# %%
# DECISION TREE

dt = tree.DecisionTreeClassifier()
dt = dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)
acc_dt=accuracy_score(y_test,y_pred)
"""fpr, tpr, thresholds = roc_curve(y_test,y_pred)

plt.plot([0, 1],[0, 1],'k--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for DECISION TREE')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')

plt.grid(True)"""

acc['DECISION TREE CLASSIFIER']=accuracy_score(y_test, y_pred) * 100

print('\nDECISION TREE CLASSIFIER Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('DECISION TREE CLASSIFIER AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('DECISION TREE CLASSIFIER Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# DECISION TREE CLASSIFIER Accuracy: 82.40%
# DECISION TREE CLASSIFIER Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       125
#            1       0.75      0.85      0.80       125
#            2       0.73      0.70      0.72       125
#            3       0.89      0.83      0.86       125
#
#    micro avg       0.82      0.82      0.82       500
#    macro avg       0.83      0.82      0.82       500
# weighted avg       0.83      0.82      0.82       500

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for DECISION TREE CLASSIFIER'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[114  11   0   0]
#  [  7 106  12   0]
#  [  0  24  88  13]
#  [  0   0  21 104]]

# %%
# Linear Discriminant Analysis

lda=LinearDiscriminantAnalysis()
lda.fit(X_train,y_train)

y_pred = lda.predict(X_test)
acc_lda=accuracy_score(y_test,y_pred)
"""fpr, tpr, thresholds = roc_curve(y_test,y_pred)

plt.plot([0, 1],[0, 1],'k--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.rcParams['font.size'] = 14

plt.title('ROC curve for Linear Discriminant Analysis')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')

plt.grid(True)
"""
acc['Linear Discriminant Analysis']=accuracy_score(y_test, y_pred) * 100

print('\nLinear Discriminant Analysis Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('Linear Discriminant Analysis  AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('Linear Discriminant Analysis Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# Linear Discriminant Analysis Accuracy: 94.80%
# Linear Discriminant Analysis Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       125
#            1       0.92      0.96      0.94       125
#            2       0.92      0.95      0.93       125
#            3       0.99      0.92      0.95       125
#
#    micro avg       0.95      0.95      0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for Linear Discriminant Analysis'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[120   5   0   0]
#  [  4 120   1   0]
#  [  0   5 119   1]
#  [  0   0  10 115]]

# %%
# GRADIENT BOOSTING CLASSIFIER

gbc=GradientBoostingClassifier()
gbc.fit(X_train,y_train)

y_pred = gbc.predict(X_test)
acc_gbc=accuracy_score(y_test,y_pred)
'''fpr, tpr, thresholds = roc_curve(y_pred, y_test)
roc_auc = auc(fpr, tpr)

#plt.figure()
plt.plot(fpr, tpr, color='darkorange', 
         label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',  linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

plt.grid(True)'''

acc['GRADIENT BOOSTING CLASSIFIER']=accuracy_score(y_test, y_pred) * 100

print('\nGRADIENT BOOSTING CLASSIFIER Accuracy: {:.2f}%'.format(accuracy_score(y_test, y_pred) * 100))
#print('GRADIENT BOOSTING CLASSIFIE AUC: {:.2f}%'.format(roc_auc_score(y_test, y_pred) * 100))
print('GRADIENT BOOSTING CLASSIFIER Classification report:\n\n', classification_report(y_test, y_pred))
# Out:
# GRADIENT BOOSTING CLASSIFIER Accuracy: 89.80%
# GRADIENT BOOSTING CLASSIFIER Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       125
#            1       0.84      0.93      0.88       125
#            2       0.84      0.86      0.85       125
#            3       0.96      0.88      0.92       125
#
#    micro avg       0.90      0.90      0.90       500
#    macro avg       0.90      0.90      0.90       500
# weighted avg       0.90      0.90      0.90       500

# %%
cm= confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
print(confusion_matrix(y_test, y_pred))
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for GRADIENT BOOSTING CLASSIFIER'); 
ax.xaxis.set_ticklabels(['0','1','2','3']); ax.yaxis.set_ticklabels(['0','1','2','3']);
# Out:
# [[116   9   0   0]
#  [  3 116   6   0]
#  [  0  13 107   5]
#  [  0   0  15 110]]

# %%
print("Accuracy score for SUPPORT VECTOR MACHINE:",acc_svc)
print(" \nAccuracy score for DECISION TREE:",acc_dt)
print(" \nAccuracy score for LOGISTIC REGRESSION:",acc_lr)
print(" \nAccuracy score for NAIVE BAYES:",acc_nb)
print(" \nAccuracy score for GRADIENT BOOSTING CLASSIFIER:",acc_gbc)
print(" \nAccuracy score for STOCHASTIC GRADIENT DESCENT:",acc_sgd)
print(" \nAccuracy score for K NEAREST NEIGHBOR:",acc_knn)
print(" \nAccuracy score for RANDOM FOREST:",acc_knn)
print(" \nAccuracy score for Linear Discriminant Analysis:",acc_lda)
# Out:
# Accuracy score for SUPPORT VECTOR MACHINE: 0.97
#
# Accuracy score for DECISION TREE: 0.824
#
# Accuracy score for LOGISTIC REGRESSION: 0.802
#
# Accuracy score for NAIVE BAYES: 0.818
#
# Accuracy score for GRADIENT BOOSTING CLASSIFIER: 0.898
#
# Accuracy score for STOCHASTIC GRADIENT DESCENT: 0.452
#
# Accuracy score for K NEAREST NEIGHBOR: 0.908
#
# Accuracy score for RANDOM FOREST: 0.908
#
# Accuracy score for Linear Discriminant Analysis: 0.948
